# %%
import pandas as pd
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [markdown]
# ## Step 1: Data Cleaning

# %% [markdown]
# ### Choose year range from 2006-2020

# %%
YEAR_MIN = 2006
YEAR_MAX = 2020

# %% [markdown]
# ### Choose one of the targets that you worked in Phase 1
#
# **Target: 4.1** By 2030, ensure that all girls and boys complete free, equitable and quality primary and secondary education leading to relevant and effective learning outcomes
#
# **Related indicator**: Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)

# %%
INDICATOR = 'Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)'

# %%
df = pd.read_excel('Target4.4.xlsx', engine='openpyxl').dropna(how='all')
df = df[df['Series Name'].eq(INDICATOR)]
print(df.shape)
df.head()
# Out:
# (266, 22)
#                                            Series Name        Series Code  \
# 532  Educational attainment, at least completed upp...  SE.SEC.CUAT.UP.ZS
# 533  Educational attainment, at least completed upp...  SE.SEC.CUAT.UP.ZS
# 534  Educational attainment, at least completed upp...  SE.SEC.CUAT.UP.ZS
# 535  Educational attainment, at least completed upp...  SE.SEC.CUAT.UP.ZS
# 536  Educational attainment, at least completed upp...  SE.SEC.CUAT.UP.ZS
#
#        Country Name Country Code  2004 [YR2004]  2005 [YR2005]  2006 [YR2006]  \
# 532     Afghanistan          AFG            NaN            NaN            NaN
# 533         Albania          ALB            NaN            NaN            NaN
# 534         Algeria          DZA            NaN            NaN      24.152861
# 535  American Samoa          ASM            NaN            NaN            NaN
# 536         Andorra          AND      51.454182      43.910172      49.950649
#
#      2007 [YR2007]  2008 [YR2008]  2009 [YR2009]  ...  2012 [YR2012]  \
# 532            NaN            NaN            NaN  ...            NaN
# 533            NaN      39.889320            NaN  ...      45.279148
# 534            NaN      25.416519            NaN  ...            NaN
# 535            NaN            NaN            NaN  ...            NaN
# 536            NaN            NaN            NaN  ...            NaN
#
#      2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 532            NaN            NaN            NaN            NaN
# 533            NaN            NaN            NaN            NaN
# 534            NaN            NaN            NaN            NaN
# 535            NaN            NaN            NaN            NaN
# 536            NaN       47.83741        47.5452      47.349689
#
#      2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  2021 [YR2021]
# 532            NaN            NaN            NaN            NaN        9.46131
# 533            NaN            NaN            NaN            NaN            NaN
# 534            NaN            NaN            NaN            NaN            NaN
# 535            NaN            NaN            NaN            NaN            NaN
# 536            NaN            NaN            NaN            NaN            NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Remove the data of  countries which have 3 or less values for chosen indicator

# %%
df = df.set_index('Country Code').filter(like='20')
df.columns = df.columns.str[:4].astype(int)
df = df.loc[:, YEAR_MIN:YEAR_MAX]
df = df[(~df.isna()).sum(axis=1) > 3]
df
# Out:
#                    2006       2007       2008       2009       2010  \
# Country Code
# AND           49.950649        NaN        NaN        NaN        NaN
# ARM                 NaN        NaN        NaN        NaN        NaN
# AUS           66.713837  68.189781  70.088959  70.855743  72.798973
# AUT                 NaN  73.590607  72.469460  75.810188  76.556099
# AZE                 NaN  88.435417  88.540138  88.610489  88.645401
# ...                 ...        ...        ...        ...        ...
# USA           85.723228        NaN  86.614128  86.709084  87.149406
# URY           24.739000        NaN  26.977221  27.750971  27.173599
# UZB                 NaN        NaN        NaN        NaN        NaN
# VEN           35.090542  39.782742  41.443661  42.987709        NaN
# PSE           31.219351  32.052090  32.759670  35.011539  34.950871
#
#                    2011       2012       2013       2014       2015  \
# Country Code
# AND                 NaN        NaN        NaN  47.837410  47.545200
# ARM           90.237610        NaN        NaN        NaN  91.837433
# AUS           74.061668  76.483017  72.037354  73.595963  75.547577
# AUT           76.427696  76.975113  77.306358  78.426590  79.012901
# AZE           88.658783  88.713089  88.719742  88.714172  88.665077
# ...                 ...        ...        ...        ...        ...
# USA           87.590889  87.679100  88.150307  88.313583  88.411972
# URY           27.018459  27.543711  27.578899  28.453150  28.747761
# UZB                 NaN        NaN  91.540611  91.947632  92.079582
# VEN                 NaN        NaN        NaN        NaN  55.793270
# PSE           36.356049  38.024212  38.507149  37.956551  39.021870
#
#                    2016       2017       2018       2019       2020
# Country Code
# AND           47.349689        NaN        NaN        NaN        NaN
# ARM                 NaN  90.096649        NaN        NaN  89.880859
# AUS           76.418037  77.261360  78.325760  79.047928  80.053032
# AUT           79.368980  79.662582        NaN  80.674049        NaN
# AZE           88.664452  88.501228  88.430939  88.419579        NaN
# ...                 ...        ...        ...        ...        ...
# USA           89.092361        NaN  89.805359        NaN  90.940521
# URY           28.747801  30.018440  30.441191  31.510580        NaN
# UZB           92.564621        NaN  96.149246  96.676292        NaN
# VEN           61.924599        NaN        NaN        NaN        NaN
# PSE           39.635609  40.620838  42.601688        NaN  45.904171
#
# [82 rows x 15 columns]

# %% [markdown]
# ### Impute your data using all of the following methods.
# Each of the method will give you an imputed dataset (i.e. you need to save the imputed data into a file). For the next step, you will work with imputed datasets obtain by applying the following methods.
# #### Constant value
# * Mean
# * Median
# #### Time-series based
# * Forward fill
# * Backward fill
# #### Advanced Method
# * Linear regression
# * Linear interpolation (extra)

# %%
df_mean = df.T.fillna(df.mean(axis=1)).T
df_median = df.T.fillna(df.median(axis=1)).T
df_ffil = df.fillna(method='ffill', axis='columns').fillna(method='bfill', axis='columns') # do bfill to fill empty values in the beginning
df_bfil = df.fillna(method='bfill', axis='columns').fillna(method='ffill', axis='columns') # do ffill to fill empty values in the end
df_regr = pd.DataFrame(
    IterativeImputer(imputation_order='roman').fit_transform(df),
    index=df.index, columns=df.columns
)

# Additinally, data imputation by linear interploation was performed
df_lint = df.interpolate(method='linear', axis='columns').fillna(method='bfill', axis='columns') # do bfill to fill empty values in the beginning

# %% [markdown]
# ### Each of these dataframes need to be saved in multiple files

# %%
df_mean.to_csv('t4_upsec_mean.csv')
df_median.to_csv('t4_upsec_median.csv')
df_ffil.to_csv('t4_upsec_ffil.csv')
df_bfil.to_csv('t4_upsec_bfil.csv')
df_lint.to_csv('t4_upsec_lint.csv')
df_regr.to_csv('t4_upsec_regr.csv')
